# %%
import pandas as pd

# %%
df = pd.read_csv('csv/words.csv')
df
# Out:
#              word familarity  cn_meaning  \
# 0         fervent          F   情感强烈的，热烈的
# 1       alleviate          F          减轻
# 2      contagious          F         传染的
# 3        pedantic          F       卖弄知识的
# 4        unwieldy          F    体积庞大而笨重的
# 5      vociferous          F       吵吵嚷嚷的
# 6         profess          F          宣称
# 7      obseisance          F       尊敬，敬意
# 8         diffuse          T         分散的
# 9       fulminate          F       抨击，辱骂
# 10        voluble          F     健谈的，话多的
# 11       sterling          F        高质量的
# 12       surmount          F       克服，战胜
# 13         prying          F         窥视的
# 14        inhibit          F       抑制，限制
# 15        censure          F          批评
# 16    peripatetic          F          巡游
# 17      stringent          F       非常严格的
# 18        dwindle          F       减少，下降
# 19      underrate          F          低估
# 20      incursion          F       侵入，侵犯
# 21       pastiche          F     【贬】模仿作品
# ...

# %%
'sleek' in list(df['word'])
# Out:
# True

# %%
def search():
    df = pd.read_csv('csv/words.csv')
